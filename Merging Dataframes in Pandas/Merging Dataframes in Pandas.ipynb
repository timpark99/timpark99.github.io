# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'/Users/timothypark/Documents/portfolios/timpark99.github.io/Merging Dataframes in Pandas/100.csv')
df1
# Out:
#    Employee ID              Name       Played By
# 0         1001       Gale Cleven  Austiin Butler
# 1         1002         John Egan   Callum Turner
# 2         1003      Harry Crosby   Anthony Boyle
# 3         1004  Robert Rosenthal       Nate Mann

# %%
df2 = pd.read_csv(r'/Users/timothypark/Documents/portfolios/timpark99.github.io/Merging Dataframes in Pandas/100 v2.csv')
df2
# Out:
#    Employee ID            Name  Age
# 0         1001     Gale Cleven   32
# 1         1002       John Egan   34
# 2         1006  Curtis Biddick   31
# 3         1007   Harold Huglin   47
# 4         1008   Marvin Bowman   44

# %%
# the df left of merge is automatically going to be our left dataframe
# the df in the parentheses is our right dataframe
# this defaults to an inner join
# x and y show up for Name because we're not merging on that column

df1.merge(df2, how='inner', on='Employee ID')
# Out:
#    Employee ID       Name_x       Played By       Name_y  Age
# 0         1001  Gale Cleven  Austiin Butler  Gale Cleven   32
# 1         1002    John Egan   Callum Turner    John Egan   34

# %%
# if we create a list on the "on", it'll look like the previous example

df1.merge(df2, how='inner', on=['Employee ID', 'Name'])
# Out:
#    Employee ID         Name       Played By  Age
# 0         1001  Gale Cleven  Austiin Butler   32
# 1         1002    John Egan   Callum Turner   34

# %%
# outer join
# NaN means not a member

df1.merge(df2, how='outer')
# Out:
#    Employee ID              Name       Played By   Age
# 0         1001       Gale Cleven  Austiin Butler  32.0
# 1         1002         John Egan   Callum Turner  34.0
# 2         1003      Harry Crosby   Anthony Boyle   NaN
# 3         1004  Robert Rosenthal       Nate Mann   NaN
# 4         1006    Curtis Biddick             NaN  31.0
# 5         1007     Harold Huglin             NaN  47.0
# 6         1008     Marvin Bowman             NaN  44.0

# %%
# left join

df1.merge(df2, how='left')
# Out:
#    Employee ID              Name       Played By   Age
# 0         1001       Gale Cleven  Austiin Butler  32.0
# 1         1002         John Egan   Callum Turner  34.0
# 2         1003      Harry Crosby   Anthony Boyle   NaN
# 3         1004  Robert Rosenthal       Nate Mann   NaN

# %%
# right join

df1.merge(df2, how='right')
# Out:
#    Employee ID            Name       Played By  Age
# 0         1001     Gale Cleven  Austiin Butler   32
# 1         1002       John Egan   Callum Turner   34
# 2         1006  Curtis Biddick             NaN   31
# 3         1007   Harold Huglin             NaN   47
# 4         1008   Marvin Bowman             NaN   44

# %%
# cross join takes each value from left dataframe and compares it to each value in the right dataframe
# very few reasons for a cross join

df1.merge(df2, how='cross')
# Out:
#     Employee ID_x            Name_x       Played By  Employee ID_y  \
# 0            1001       Gale Cleven  Austiin Butler           1001
# 1            1001       Gale Cleven  Austiin Butler           1002
# 2            1001       Gale Cleven  Austiin Butler           1006
# 3            1001       Gale Cleven  Austiin Butler           1007
# 4            1001       Gale Cleven  Austiin Butler           1008
# 5            1002         John Egan   Callum Turner           1001
# 6            1002         John Egan   Callum Turner           1002
# 7            1002         John Egan   Callum Turner           1006
# 8            1002         John Egan   Callum Turner           1007
# 9            1002         John Egan   Callum Turner           1008
# 10           1003      Harry Crosby   Anthony Boyle           1001
# 11           1003      Harry Crosby   Anthony Boyle           1002
# 12           1003      Harry Crosby   Anthony Boyle           1006
# 13           1003      Harry Crosby   Anthony Boyle           1007
# 14           1003      Harry Crosby   Anthony Boyle           1008
# 15           1004  Robert Rosenthal       Nate Mann           1001
# 16           1004  Robert Rosenthal       Nate Mann           1002
# 17           1004  Robert Rosenthal       Nate Mann           1006
# 18           1004  Robert Rosenthal       Nate Mann           1007
# 19           1004  Robert Rosenthal       Nate Mann           1008
#
#             Name_y  Age
# 0      Gale Cleven   32
# 1        John Egan   34
# 2   Curtis Biddick   31
# 3    Harold Huglin   47
# 4    Marvin Bowman   44
# 5      Gale Cleven   32
# 6        John Egan   34
# 7   Curtis Biddick   31
# 8    Harold Huglin   47
# 9    Marvin Bowman   44
# 10     Gale Cleven   32
# 11       John Egan   34
# 12  Curtis Biddick   31
# 13   Harold Huglin   47
# 14   Marvin Bowman   44
# 15     Gale Cleven   32
# 16       John Egan   34
# 17  Curtis Biddick   31
# 18   Harold Huglin   47
# 19   Marvin Bowman   44

# %%
# join does not have default values like merge, so we must type everything in
# join is better when you're working with indexes

df1.join(df2, on='Employee ID', how='outer', lsuffix='_Left', rsuffix='_Right')
# Out:
#      Employee ID  Employee ID_Left         Name_Left       Played By  \
# 0.0         1001            1001.0       Gale Cleven  Austiin Butler
# 1.0         1002            1002.0         John Egan   Callum Turner
# 2.0         1003            1003.0      Harry Crosby   Anthony Boyle
# 3.0         1004            1004.0  Robert Rosenthal       Nate Mann
# NaN            0               NaN               NaN             NaN
# NaN            1               NaN               NaN             NaN
# NaN            2               NaN               NaN             NaN
# NaN            3               NaN               NaN             NaN
# NaN            4               NaN               NaN             NaN
#
#      Employee ID_Right      Name_Right   Age
# 0.0                NaN             NaN   NaN
# 1.0                NaN             NaN   NaN
# 2.0                NaN             NaN   NaN
# 3.0                NaN             NaN   NaN
# NaN             1001.0     Gale Cleven  32.0
# NaN             1002.0       John Egan  34.0
# NaN             1006.0  Curtis Biddick  31.0
# NaN             1007.0   Harold Huglin  47.0
# NaN             1008.0   Marvin Bowman  44.0

# %%
# join by using index

df4 = df1.set_index('Employee ID').join(df2.set_index('Employee ID'), lsuffix='_Left', rsuffix='_Right', how='outer')
df4
# Out:
#                     Name_Left       Played By      Name_Right   Age
# Employee ID
# 1001              Gale Cleven  Austiin Butler     Gale Cleven  32.0
# 1002                John Egan   Callum Turner       John Egan  34.0
# 1003             Harry Crosby   Anthony Boyle             NaN   NaN
# 1004         Robert Rosenthal       Nate Mann             NaN   NaN
# 1006                      NaN             NaN  Curtis Biddick  31.0
# 1007                      NaN             NaN   Harold Huglin  47.0
# 1008                      NaN             NaN   Marvin Bowman  44.0

# %%
# concatenate is like putting one dataframe on top of another
# inner only keeps columns that are the same
# outer keeps all columns
# 0 axis is lefthand index
# 1 axis is the top index which are columns

pd.concat([df1,df2], join='outer', axis=1)
# Out:
#    Employee ID              Name       Played By  Employee ID            Name  \
# 0       1001.0       Gale Cleven  Austiin Butler         1001     Gale Cleven
# 1       1002.0         John Egan   Callum Turner         1002       John Egan
# 2       1003.0      Harry Crosby   Anthony Boyle         1006  Curtis Biddick
# 3       1004.0  Robert Rosenthal       Nate Mann         1007   Harold Huglin
# 4          NaN               NaN             NaN         1008   Marvin Bowman
#
#    Age
# 0   32
# 1   34
# 2   31
# 3   47
# 4   44
