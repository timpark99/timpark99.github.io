# %% [markdown]
# # **Unicorn Companies**
#
# This activity uses a dataset called Unicorn_Companies.csv. It represents a list of private companies with a value of over 1 billion dollars as of March 2022. The data includes the name of the country where the company was founded, its current valuation, funding, industry, top investors, year it was founded, and the year it reached a $1 billion valuation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

df = pd.read_csv('/Users/timothypark/Documents/portfolios/timpark99.github.io/Unicorn Companies/unicorn_companies.csv')

# %%
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B      4/7/17          Artificial intelligence
# 1     SpaceX     $100B     12/1/12                            Other
# 2      SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3     Stripe      $95B     1/23/14                          Fintech
# 4     Klarna      $46B    12/12/11                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
df.size
# Out:
# 10740

# %%
df.shape
# Out:
# (1074, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %% [markdown]
# Notice the Dtypes for Valuation, Date Joined, Year Founded and Funding.  All these Dtypes may need to be manipulated for future calculations

# %%
df.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %% [markdown]
# ### Convert the `Date Joined` column to datetime
#
# - Use pd.to_datetime() to convert the "Date Joined" column to datetime.
# - Update the column with the converted values.
# - Use .info() to confirm that the update actually took place
#
# You can use the `to_datetime()` function from the `pandas` library. This splits each value into year, month, and date components. This is an important step in data cleaning, as it makes the data in this column easier to use in tasks you may encounter. To name a few examples, you may need to compare "date joined" between companies or determine how long it took a company to become a unicorn. Having "date joined" in datetime form would help you complete such tasks.

# %%
df["Date Joined"] = pd.to_datetime(df["Date Joined"])
# Out:
# /var/folders/5z/f5jycvmd0x58dvn1by8xk79h0000gn/T/ipykernel_27386/860117670.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date Joined"] = pd.to_datetime(df["Date Joined"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %% [markdown]
# ### Create a `Year Joined` column
#
# It is common to encounter situations where you will need to compare the year joined with the year founded. The `Date Joined` column does not just have year—it has the year, month, and date. Extract the year component from the `Date Joined` column and add those year components into a new column to keep track of each company's year joined.

# %%
df["Year Joined"] = df["Date Joined"].dt.year

# confirm new column "Year Joined"
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined
# 0  Sequoia Capital China, SIG Asia Investments, S...         2017
# ...

# %% [markdown]
# ### Take a sample of the data
#
# It is not necessary to take a sample of the data in order to conduct the visualizations and EDA that follow. But you may encounter scenarios in the future where you will need to take a sample of the data due to time and resource limitations. For the purpose of developing your skills around sampling, take a sample of the data and work with that sample for the next steps of analysis you want to conduct. Use the `sample()` function for this task.
#
# - Use `sample()` with the `n` parameter set to `50` to randomly sample 50 unicorn companies from the data. Be sure to specify the `random_state` parameter to ensure reproducibility of your work. Save the result to a variable called `df_sampled`.

# %%
df_sampled = df.sample(n=50, random_state=0)

# %% [markdown]
# Specifying n is specifying how many random rows you want to return

# %%
df.sample(n=2)
# Out:
#               Company Valuation Date Joined                      Industry  \
# 333  Cross River Bank       $3B  2022-02-11                       Fintech
# 28          Grammarly      $13B  2019-10-10  Internet software & services
#
#               City Country/Region      Continent  Year Founded Funding  \
# 333       Fort Lee  United States  North America          2008   $775M
# 28   San Francisco  United States  North America          2009   $400M
#
#                                       Select Investors  Year Joined
# 333  Battery Ventures, Andreessen Horowitz, Ribbit ...         2022
# 28   General Catalyst, Institutional Venture Partne...         2019

# %% [markdown]
# if I do it again, I get another set of random rows

# %%
df.sample(n=2)
# Out:
#      Company Valuation Date Joined                         Industry     City  \
# 137   Vinted       $5B  2019-11-27  E-commerce & direct-to-consumer  Vilnius
# 561  Everlaw       $2B  2020-03-10     Internet software & services  Oakland
#
#     Country/Region      Continent  Year Founded Funding  \
# 137      Lithuania         Europe          2008   $562M
# 561  United States  North America          2010   $299M
#
#                                       Select Investors  Year Joined
# 137  Accel, Insight Partners, Burda Principal Inves...         2019
# 561   K9 Ventures, Menlo Ventures, Andreessen Horowitz         2020

# %% [markdown]
# Instead of specifying `n`, you can specify `frac` which tells pandas what fraction of your dataframe you want randomly returned to you.  Here I'm setting frac to 0.01 or 1%.  Since the total is 1074 it'll round up to show a sample size of 11.

# %%
df.sample(frac=0.01)
# Out:
#                   Company Valuation Date Joined                      Industry  \
# 744   The Brandtech Group       $1B  2019-11-19                         Other
# 1060     Weights & Biases       $1B  2021-10-13  Internet software & services
# 222                Branch       $4B  2018-09-10   Mobile & telecommunications
# 104              WeDoctor       $6B  2015-09-22                        Health
# 623               JimuBox       $1B  2015-04-21                       Fintech
# 1014              SaltPay       $1B  2021-04-09                       Fintech
# 946              JoyTunes       $1B  2021-06-21                        Edtech
# 707         Salt Security       $1B  2022-02-10                 Cybersecurity
# 25                  Plaid      $13B  2018-12-11                       Fintech
# 1045            Timescale       $1B  2022-02-22  Internet software & services
# 87                   CRED       $7B  2021-04-06                       Fintech
#
# ...

# %% [markdown]
# By default, pandas will only select a random row once.  However, if you wanted to select the same row more than once, you can set replace=True.

# %%
df.sample(n=5, replace=True)
# Out:
#                           Company Valuation Date Joined  \
# 306  Eruditus Executive Education       $3B  2021-08-12
# 431         Mobile Premier League       $2B  2021-09-15
# 273                          Oura       $3B  2022-04-05
# 470                       Carsome       $2B  2021-07-12
# 175                        Kraken       $4B  2019-06-25
#
#                             Industry           City Country/Region  \
# 306                           Edtech         Mumbai          India
# 431     Internet software & services      Bengaluru          India
# 273                           Health           Oulu        Finland
# 470  E-commerce & direct-to-consumer       Selangor       Malaysia
# 175                          Fintech  San Francisco  United States
#
#          Continent  Year Founded Funding  \
# 306           Asia          2010   $591M
# 431           Asia          2018   $376M
# 273         Europe          2013   $148M
# 470           Asia          2015   $577M
# ...

# %% [markdown]
# By default pandas give each row and equal chance of being selected but if you wanted one specific row to have a higher chance of getting selected then you can use weights.  Here we will have Asia be 5 times more likely to get selected over the other countries.

# %%
weights = {'Asia' : 5,
           'North America' : 1,
           'Europe' : 1,
           'Oceania' : 1,
           'South America' : 1,
           'Africa' : 1}
df['weights'] = df['Continent'].apply(lambda x: weights[x])

# show new column of "weights"
df.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Year Joined  weights
# ...

# %% [markdown]
# Here I'll pull a random sample of 3 rows from my DataFrame and pass my weights column.  I set random state to make sure I get the same random numbers each time.

# %%
df.sample(n=3, weights='weights', random_state=99)
# Out:
#         Company Valuation Date Joined                         Industry  \
# 726      GPclub       $1B  2018-10-22                            Other
# 577  Magic Leap       $2B  2014-10-21                         Hardware
# 893       Cider       $1B  2021-09-02  E-commerce & direct-to-consumer
#
#            City Country/Region      Continent  Year Founded Funding  \
# 726       Seoul    South Korea           Asia          2003    $67M
# 577  Plantation  United States  North America          2010     $3B
# 893         NaN      Hong Kong           Asia          2020   $140M
#
#                                       Select Investors  Year Joined  weights
# 726                                      Goldman Sachs         2018        5
# 577  Obvious Ventures, Qualcomm Ventures, Andreesse...         2014        1
# 893       Andreessen Horowitz, DST Global, IDG Capital         2021        5

# %% [markdown]
# To get random columns instead of rows, just set axis=1

# %%
df.sample(n=2, axis=1)
# Out:
#      Date Joined Valuation
# 0     2017-04-07     $180B
# 1     2012-12-01     $100B
# 2     2018-07-03     $100B
# 3     2014-01-23      $95B
# 4     2011-12-12      $46B
# ...          ...       ...
# 1069  2017-06-29       $1B
# 1070  2017-04-18       $1B
# 1071  2021-05-06       $1B
# 1072  2021-10-19       $1B
# 1073  2020-09-16       $1B
#
# [1074 rows x 2 columns]

# %% [markdown]
# ### Visualize the time it took companies to reach unicorn status
#
# Visualize the longest time it took companies to reach unicorn status for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. You'll first need to prepare the data.

# %%
# Create new `years_till_unicorn` column 
df_sampled["years_till_unicorn"] = df_sampled["Year Joined"] - df_sampled["Year Founded"]

# Group the data by `Industry`. For each industry, get the max value in the `years_till_unicorn` column.
grouped = (df_sampled[["Industry", "years_till_unicorn"]]
           .groupby("Industry")
           .max()
           .sort_values(by="years_till_unicorn")
          )
grouped
# Out:
#                                      years_till_unicorn
# Industry
# Data management & analytics                           3
# Artificial intelligence                               5
# Auto & transportation                                 6
# Cybersecurity                                         6
# Hardware                                              7
# Mobile & telecommunications                           8
# Health                                               11
# E-commerce & direct-to-consumer                      12
# Other                                                15
# Fintech                                              17
# Internet software & services                         17
# Supply chain, logistics, & delivery                  19

# %%
# Create bar plot
# with Industry column as the categories of the bars
# and the difference in years between Year Joined column and Year Founded column as the heights of the bars

plt.bar(grouped.index, grouped["years_till_unicorn"])

# Set title
plt.title("Bar plot of maximum years taken by company to become unicorn per industry (from sample)")

# Set x-axis label
plt.xlabel("Industry")

# Set y-axis label
plt.ylabel("Maximum number of years")

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text  
plt.xticks(rotation=45, horizontalalignment='right')

# Display the plot
plt.show()

# %% [markdown]
# ### Visualize the maximum unicorn company valuation per industry
#
# Visualize unicorn companies' maximum valuation for each industry represented in the sample. To create a bar plot to visualize this, use the `bar()` function from the `matplotlib.pyplot` module. Before plotting, create a new column that represents the companies' valuations as numbers (instead of strings, as they're currently represented). Then, use this new column to plot your data.

# %%
# Create a column representing company valuation as numeric data

# Create new column
df_sampled['valuation_billions'] = df_sampled['Valuation']
# Remove the '$' from each value
df_sampled['valuation_billions'] = df_sampled['valuation_billions'].str.replace('$', '')
# Remove the 'B' from each value
df_sampled['valuation_billions'] = df_sampled['valuation_billions'].str.replace('B', '')
# Convert column to type int
df_sampled['valuation_billions'] = df_sampled['valuation_billions'].astype('int')
df_sampled.head()
# Out:
#           Company Valuation Date Joined                      Industry  \
# 239        Zapier       $4B  2021-01-14  Internet software & services
# 642   TalkingData       $1B  2021-01-06   Mobile & telecommunications
# 722      Signifyd       $1B  2021-04-15                       Fintech
# 484          Wave       $2B  2021-09-07                       Fintech
# 984  Omada Health       $1B  2022-02-23                        Health
#
#               City Country/Region      Continent  Year Founded Funding  \
# 239      Sunnyvale  United States  North America          2011     $1M
# 642        Beijing          China           Asia          2013   $310M
# 722       San Jose  United States  North America          2011   $390M
# 484          Dakar        Senegal         Africa          2018   $200M
# 984  San Francisco  United States  North America          2011   $449M
#
#                                       Select Investors  Year Joined  \
# ...

# %% [markdown]
# Now, prepare the data for modeling by performing the necessary calculations on it.

# %%
# Prepare data for modeling
grouped = (df_sampled[["Industry", "valuation_billions"]]
           .groupby("Industry")
           .max()
           .sort_values(by="valuation_billions")
          )
grouped
# Out:
#                                      valuation_billions
# Industry
# Cybersecurity                                         1
# Hardware                                              1
# Auto & transportation                                 2
# Mobile & telecommunications                           2
# Supply chain, logistics, & delivery                   2
# Other                                                 3
# Data management & analytics                           4
# Fintech                                               4
# Health                                                5
# Internet software & services                          5
# Artificial intelligence                              12
# E-commerce & direct-to-consumer                      13

# %%
# Create bar plot
# with Industry column as the categories of the bars
# and new valuation column as the heights of the bars

plt.bar(grouped.index, grouped["valuation_billions"])

# Set title
plt.title("Bar plot of maximum unicorn company valuation per industry (from sample)")

# Set x-axis label
plt.xlabel("Industry")

# Set y-axis label
plt.ylabel("Maximum valuation in billions of dollars")

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text  
plt.xticks(rotation=45, horizontalalignment='right')

# Display the plot
plt.show()
