# %% [markdown]
# # Dataframes with Pandas - Students Health and Academic Performance
#
# This dataset explores the relationship between students' health and their academic performance. It contains multiple rows of data, each representing a student, and multiple columns.  This dataset can be used to analyze the impact of health on academic success, identify potential predictors of academic performance, and inform interventions to support students' overall well-being and academic achievement.

# %%
import pandas as pd
import numpy as np

# %%
android = pd.read_csv('/Users/timothypark/Documents/portfolios/timpark99.github.io/Dataframes in Pandas/Android.csv')

# inspect the first 5 rows
android.head()
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0        Ali  21-25    Male           Yes                  Android
# 1      Bilal  21-25    Male           Yes                  Android
# 2   Abdullah  21-25    Male           Yes                  Android
# 3     Aammar  21-25    Male           Yes                  Android
# 4  Jehanzaib  21-25    Male           Yes                  Android
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            Social Media                  Yes
# 1                      Sometimes            Social Media                  Yes
# 2                     Frequently            All of these                  Yes
# 3                         Rarely            All of these                  Yes
# 4                         Rarely            All of these                  Yes
#
#      Educational Apps Daily usages Performance impact      Usage distraction  \
# 0  Educational Videos    4-6 hours              Agree           During Exams
# 1  Educational Videos    4-6 hours            Neutral           During Exams
# 2  Educational Videos    2-4 hours     Strongly agree  During Class Lectures
# 3  Educational Videos    > 6 hours            Neutral        Not Distracting
# 4  Educational Videos    2-4 hours  Strongly disagree         While Studying
#
#   Attention span   Useful features    Health Risks Beneficial subject  \
# 0            Yes            Camera             Yes         Accounting
# 1            Yes  Notes Taking App             Yes  Browsing Material
# 2             No   Internet Access  Only Partially           Reasarch
# 3            Yes   Internet Access  Only Partially           Reasarch
# 4            Yes            Camera  Only Partially           Reasarch
#
#   Usage symptoms Symptom frequency                 Health precautions  \
# 0       Headache             Never            Using Blue light filter
# 1   All of these         Sometimes  Taking Break during prolonged use
# 2            NaN             Never               Limiting Screen Time
# 3       Headache         Sometimes                      None of Above
# 4       Headache        Frequently                      None of Above
#
#   Health rating
# 0     Excellent
# 1          Good
# 2     Excellent
# 3          Good
# 4     Excellent

# %%
# the info method examines the number of rows and columns, the column names, the data type contained in each column, the number of non-null values in each column, and the amount of memory the dataframe uses.
android.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Names                           81 non-null     object
#  1   Age                             81 non-null     object
#  2   Gender                          81 non-null     object
#  3   Mobile Phone                    81 non-null     object
#  4   Mobile Operating System         81 non-null     object
#  5   Mobile phone use for education  79 non-null     object
#  6   Mobile phone activities         80 non-null     object
#  7   Helpful for studying            79 non-null     object
#  8   Educational Apps                79 non-null     object
#  9   Daily usages                    80 non-null     object
#  10  Performance impact              79 non-null     object
#  11  Usage distraction               79 non-null     object
#  12  Attention span                  80 non-null     object
#  13  Useful features                 79 non-null     object
#  14  Health Risks                    79 non-null     object
#  15  Beneficial subject              80 non-null     object
#  16  Usage symptoms                  79 non-null     object
#  17  Symptom frequency               80 non-null     object
#  18  Health precautions              80 non-null     object
#  19  Health rating                   80 non-null     object
# dtypes: object(20)
# memory usage: 12.8+ KB

# %%
# summary statistics but no numerical values in data
android.describe()
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# count     81     81      81            81                       81
# unique    81      4       2             1                        1
# top      Ali  21-25    Male           Yes                  Android
# freq       1     59      64            81                       81
#
#        Mobile phone use for education Mobile phone activities  \
# count                              79                      80
# unique                              4                       7
# top                         Sometimes            All of these
# freq                               41                      47
#
#        Helpful for studying    Educational Apps Daily usages  \
# count                    79                  79           80
# unique                    2                   4            4
# top                     Yes  Educational Videos    4-6 hours
# freq                     75                  43           32
#
#        Performance impact Usage distraction Attention span  Useful features  \
# count                  79                79             80               79
# unique                  5                 4              2                4
# top                 Agree    While Studying            Yes  Internet Access
# freq                   32                26             55               55
#
#        Health Risks Beneficial subject Usage symptoms Symptom frequency  \
# count            79                 80             79                80
# unique            3                  3              6                 4
# top             Yes           Reasarch   All of these         Sometimes
# freq             49                 39             26                42
#
#           Health precautions Health rating
# count                     80            80
# unique                     4             7
# top     Limiting Screen Time          Good
# freq                      30            35

# %%
# check how many rows there are for each symptom
android['Usage symptoms'].value_counts()
# Out:
# Usage symptoms
# All of these                                                 26
# Sleep disturbance                                            22
# Headache                                                     20
# Anxiety or Stress                                             8
# Sleep disturbance;Anxiety or Stress                           2
# Headache;Sleep disturbance;Anxiety or Stress;All of these     1
# Name: count, dtype: int64

# %%
# sort by age from oldest to youngest
age_sorted = android.sort_values(by='Age', ascending=False)
age_sorted.head()
# Out:
#       Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 59  Jamshid  31-35    Male           Yes                  Android
# 72    Sayed  31-35    Male           Yes                  Android
# 27   Khawir  31-35    Male           Yes                  Android
# 58    Jawed  26-30    Male           Yes                  Android
# 45    Sabir  26-30    Male           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 59                         Rarely            Web-browsing
# 72                         Rarely               Messaging
# 27                          Never            All of these
# 58                         Rarely            Web-browsing
# 45                      Sometimes            All of these
#
#    Helpful for studying    Educational Apps Daily usages Performance impact  \
# 59                  Yes            Language    2-4 hours                NaN
# 72                  NaN  Productivity Tools    > 6 hours  Strongly disagree
# 27                   No       Study Planner    < 2 hours            Neutral
# 58                  Yes            Language    > 6 hours              Agree
# 45                  Yes  Productivity Tools    4-6 hours              Agree
#
#    Usage distraction Attention span   Useful features    Health Risks  \
# 59      During Exams            Yes  Notes Taking App              No
# 72   Not Distracting            Yes  Notes Taking App              No
# 27   Not Distracting             No        Calculator  Only Partially
# 58      During Exams             No   Internet Access             Yes
# 45    While Studying            Yes   Internet Access  Only Partially
#
#    Beneficial subject     Usage symptoms Symptom frequency  \
# 59         Accounting  Sleep disturbance            Rarely
# 72         Accounting       All of these        Frequently
# 27         Accounting       All of these             Never
# 58           Reasarch  Anxiety or Stress            Rarely
# 45  Browsing Material  Sleep disturbance         Sometimes
#
#                    Health precautions Health rating
# 59  Taking Break during prolonged use          Fair
# 72            Using Blue light filter          Fair
# 27                      None of Above     Excellent
# 58               Limiting Screen Time          Good
# 45  Taking Break during prolonged use          Good

# %%
# using iloc to select 2 rows at indices 10 and 11
age_sorted.iloc[10:12]
# Out:
#      Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 44  Kausar  21-25  Female           Yes                  Android
# 56   Usman  21-25    Male           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 44                     Frequently            All of these
# 56                      Sometimes            Web-browsing
#
#    Helpful for studying    Educational Apps Daily usages Performance impact  \
# 44                  Yes  Productivity Tools    2-4 hours     Strongly agree
# 56                  Yes  Educational Videos    2-4 hours            Neutral
#
#         Usage distraction Attention span  Useful features Health Risks  \
# 44        Not Distracting             No  Internet Access          Yes
# 56  During Class Lectures            Yes           Camera          Yes
#
#    Beneficial subject     Usage symptoms Symptom frequency  \
# 44           Reasarch       All of these        Frequently
# 56         Accounting  Anxiety or Stress            Rarely
#
#                    Health precautions Health rating
# 44               Limiting Screen Time          Good
# 56  Taking Break during prolonged use          Fair

# %%
# create a boolean mask that only shows data when "Health precautions" is "Limiting Screen Time"
mask = age_sorted['Health precautions'] == 'Limiting Screen Time'
limit_df = age_sorted[mask]
limit_df.head()
# Out:
#      Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 58   Jawed  26-30    Male           Yes                  Android
# 34   Ameer  26-30    Male           Yes                  Android
# 44  Kausar  21-25  Female           Yes                  Android
# 52  Tufail  21-25    Male           Yes                  Android
# 47  Humara  21-25  Female           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 58                         Rarely            Web-browsing
# 34                      Sometimes            Social Media
# 44                     Frequently            All of these
# 52                          Never            Social Media
# 47                      Sometimes            All of these
#
#    Helpful for studying    Educational Apps Daily usages Performance impact  \
# 58                  Yes            Language    > 6 hours              Agree
# 34                  Yes  Educational Videos    4-6 hours              Agree
# 44                  Yes  Productivity Tools    2-4 hours     Strongly agree
# 52                  Yes            Language    2-4 hours            Neutral
# 47                  Yes  Productivity Tools    2-4 hours     Strongly agree
#
#         Usage distraction Attention span   Useful features    Health Risks  \
# 58           During Exams             No   Internet Access             Yes
# 34  During Class Lectures             No  Notes Taking App             Yes
# 44        Not Distracting             No   Internet Access             Yes
# 52  During Class Lectures             No        Calculator             Yes
# 47         While Studying            Yes            Camera  Only Partially
#
#    Beneficial subject     Usage symptoms Symptom frequency  \
# 58           Reasarch  Anxiety or Stress            Rarely
# 34         Accounting       All of these         Sometimes
# 44           Reasarch       All of these        Frequently
# 52           Reasarch       All of these             Never
# 47  Browsing Material           Headache         Sometimes
#
#       Health precautions   Health rating
# 58  Limiting Screen Time            Good
# 34  Limiting Screen Time            Good
# 44  Limiting Screen Time            Good
# 52  Limiting Screen Time  Excellent;Good
# 47  Limiting Screen Time            Fair

# %%
# first number is the number of rows and the second is the number of columns
limit_df.shape
# Out:
# (30, 20)

# %%
# calculate mode of usage symptoms when health rating is excellent
mask = limit_df['Health rating'] == 'Excellent'
limit_df[mask]['Usage symptoms'].mode()
# Out:
# 0    Headache
# Name: Usage symptoms, dtype: object

# %%
# initially encountered an error because there was a white space in the CSV file
# perform strip to remove it
android.columns = android.columns.str.strip()

# returns a random sample of items from each group
android.groupby('Gender').sample()[['Health rating']]
# Out:
#    Health rating
# 19          Good
# 4      Excellent

# %%
# add another dataframe with the same format as the original dataframe with the same columns in the same order
ios = pd.read_csv('/Users/timothypark/Documents/portfolios/timpark99.github.io/Dataframes in Pandas/iOS.csv')
ios.head()
# Out:
#      Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0   Hammad  21-25    Male           Yes                      IOS
# 1    Waqar  21-25    Male           Yes                      IOS
# 2   Fatima  21-25  Female           Yes                      IOS
# 3    Wasid  21-25    Male           Yes                      IOS
# 4  Mukhtar  21-25    Male           Yes                      IOS
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            All of these                  Yes
# 1                     Frequently            All of these                  Yes
# 2                      Sometimes            All of these                  Yes
# 3                      Sometimes            Social Media                  Yes
# 4                      Sometimes            All of these                  Yes
#
#      Educational Apps Daily usages Performance impact      Usage distraction  \
# 0  Educational Videos    4-6 hours     Strongly agree        Not Distracting
# 1  Educational Videos    > 6 hours              Agree         While Studying
# 2       Study Planner    4-6 hours              Agree        Not Distracting
# 3  Educational Videos    > 6 hours            Neutral  During Class Lectures
# 4            Language    4-6 hours            Neutral         While Studying
#
#   Attention span  Useful features Health Risks Beneficial subject  \
# 0             No           Camera          Yes  Browsing Material
# 1            Yes  Internet Access           No  Browsing Material
# 2            Yes  Internet Access           No           Reasarch
# 3            Yes  Internet Access          Yes         Accounting
# 4            Yes  Internet Access           No  Browsing Material
#
#                         Usage symptoms Symptom frequency  \
# 0                         All of these         Sometimes
# 1                    Sleep disturbance         Sometimes
# 2                    Sleep disturbance         Sometimes
# 3                    Anxiety or Stress         Sometimes
# 4  Sleep disturbance;Anxiety or Stress            Rarely
#
#                   Health precautions Health rating
# 0                      None of Above     Excellent
# 1                      None of Above     Excellent
# 2                      None of Above          Good
# 3  Taking Break during prolonged use     Excellent
# 4                      None of Above          Good

# %%
# add the new dataframe as rows beneath the old dataframe to concatenate them
# assign the result to a new combined dataframe
# verify that the length of the combined dataframe is equal to the sum of lengths of ios and android dataframes

combined_df = pd.concat([android, ios], axis=0)
len(combined_df) == len(android) + len(ios)
# Out:
# True
