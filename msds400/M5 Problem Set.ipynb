# %% [markdown]
# # Module 5 Problem Set

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 1: </b>
#
# Consider the function $f(x) = x^4 - 18x^2 + 11, -2 <= x <= 7$
#
# Find the absolute maximum of $f(x)$ on the given interval and the value of x where it occurs.
#
# Find the absolute minimum of $f(x)$ on the given interval and the value of x where it occurs.

# %%
import numpy as np

def f(x):
  """
  Calculates the value of the function f(x).

  Args:
    x: The value of x.

  Returns:
    The value of f(x).
  """

  return x**4 - 18*x**2 + 11



x_values = np.linspace(-2, 7, 100)
f_values = f(x_values)

max_value = np.max(f_values)
min_value = np.min(f_values)

max_index = np.argmax(f_values)
min_index = np.argmin(f_values)

print("The absolute maximum of f(x) is: ", max_value)
print("The x-value where the maximum occurs is: ", x_values[max_index])
print("The absolute minimum of f(x) is: ", min_value)
print("The x-value where the minimum occurs is: ", x_values[min_index])
# Out:
# The absolute maximum of f(x) is:  1530.0
# The x-value where the maximum occurs is:  7.0
# The absolute minimum of f(x) is:  -70.0
# The x-value where the minimum occurs is:  3.0

# %%
# replaced values from problem set 

import numpy as np

def f(x):
  """
  Calculates the value of the function f(x).

  Args:
    x: The value of x.

  Returns:
    The value of f(x).
  """

  return x**4 - 98*x**2 + 10



x_values = np.linspace(-6, 15, 100)
f_values = f(x_values)

max_value = np.max(f_values)
min_value = np.min(f_values)

max_index = np.argmax(f_values)
min_index = np.argmin(f_values)

print("The absolute maximum of f(x) is: ", max_value)
print("The x-value where the maximum occurs is: ", x_values[max_index])
print("The absolute minimum of f(x) is: ", min_value)
print("The x-value where the minimum occurs is: ", x_values[min_index])
# Out:
# The absolute maximum of f(x) is:  28585.0
# The x-value where the maximum occurs is:  15.0
# The absolute minimum of f(x) is:  -2390.2862931004674
# The x-value where the minimum occurs is:  6.9393939393939394

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 2: </b> The below function has only one local max and one local min. Use the first derivative test to find where they occur:
#
# $f(x) = 2x^3 - 30x^2 + 144x - 6$

# %%
import sympy as sp

def find_local_max_min():
    x = sp.Symbol('x')
    f = 2*x**3 - 30*x**2 + 144*x - 6

    # Step 1: Calculate the first derivative
    f_prime = f.diff(x)

    # Step 2: Find the critical points
    critical_points = sp.solve(f_prime, x)

    local_maxima = []
    local_minima = []

    for point in critical_points:
        # Step 3: Use the second derivative test
        f_double_prime = f_prime.diff(x)
        double_prime_value = f_double_prime.subs(x, point)

        if double_prime_value > 0:
            local_minima.append(point)
        elif double_prime_value < 0:
            local_maxima.append(point)

    return local_maxima, local_minima

# Call the function to find the local maxima and minima
maxima, minima = find_local_max_min()

print("Local Maxima:", maxima)
print("Local Minima:", minima)
# Out:
# Local Maxima: [4]
# Local Minima: [6]

# %%
# replaced values from problem set

import sympy as sp

def find_local_max_min():
    x = sp.Symbol('x')
    f = 2*x**3 - 33*x**2 + 168*x - 10

    # Step 1: Calculate the first derivative
    f_prime = f.diff(x)

    # Step 2: Find the critical points
    critical_points = sp.solve(f_prime, x)

    local_maxima = []
    local_minima = []

    for point in critical_points:
        # Step 3: Use the second derivative test
        f_double_prime = f_prime.diff(x)
        double_prime_value = f_double_prime.subs(x, point)

        if double_prime_value > 0:
            local_minima.append(point)
        elif double_prime_value < 0:
            local_maxima.append(point)

    return local_maxima, local_minima

# Call the function to find the local maxima and minima
maxima, minima = find_local_max_min()

print("Local Maxima:", maxima)
print("Local Minima:", minima)
# Out:
# Local Maxima: [4]
# Local Minima: [7]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 6: </b>
#
# Given the function $g(x) = 6x^3 - 45x^2 + 108x$, find the first derivative, $g'(x)$, $g''(2)$. Visually verify whether the concavity and maximum at $x = 2$.

# %%
# 6
from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = 6 * x **3 - 45 * x**2 + 108 * x
# g = 7(x - 5)()
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivative is {g_first}")
print(f"Second derivative is {g_second}")

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(2)

print(f"g''(2) = {p1}")

gp = plotting.plot(g, show=False, ylim=(-1000, 1000), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
# Out:
# First derivative is 18*x**2 - 90*x + 108
# Second derivative is 36*x - 90
# g''(2) = -18
# We can visually verify our interpretation of concave down and a maxima

# %%
# replaced values from problem set 


from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = 6 * x **3 - 45 * x**2 + 72 * x
# g = 7(x - 5)()
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivative is {g_first}")
print(f"Second derivative is {g_second}")

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(1)

print(f"g''(2) = {p1}")

gp = plotting.plot(g, show=False, ylim=(-1000, 1000), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
# Out:
# First derivative is 18*x**2 - 90*x + 72
# Second derivative is 36*x - 90
# g''(2) = -54
# We can visually verify our interpretation of concave down and a maxima

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 11: </b> <br/>
# Glorious Gadgets is a retailer of astronomy equipment. They purchase equipment from a supplier and then sell it to customers in their store. <br/>
#
# The function $C(x) = 3x + 91875x^-1 + 26250$ models their total inventory costs (in dollars) as a function of $x$ the lot size (the total number of pieces of astronomy equipment) for each of their orders from the supplier. The inventory costs include such things as purchasing, processing, shipping, and storing the equipment.
# What lot size should Glorious Gadgets order to minimize their total inventory costs? What is their minimum total inventory cost?

# %%
import math
def C(x):
  """
  Calculates the total inventory costs C for a given lot size x.

  Args:
    x: The lot size.

  Returns:
    The total inventory costs C.
  """

  return 3 * x + 91875 / x + 26250

min_cost = math.inf
min_lot_size = 0
for x in range(1, 10000):
    cost = C(x)
    if cost < min_cost:
      min_cost = cost
      min_lot_size = x

print("The minimum total inventory costs is", min_cost, "dollars.")
print("The minimum lot size is", min_lot_size, "pieces.")
# Out:
# The minimum total inventory costs is 27300.0 dollars.
# The minimum lot size is 175 pieces.

# %%
# replace values from problem set 
import math

def C(x):
  """
  Calculates the total inventory costs C for a given lot size x.

  Args:
    x: The lot size.

  Returns:
    The total inventory costs C.
  """

  return 2.5 * x + 49000 / x + 14000

min_cost = math.inf
min_lot_size = 0
for x in range(1, 10000):
    cost = C(x)
    if cost < min_cost:
      min_cost = cost
      min_lot_size = x

print("The minimum total inventory costs is", min_cost, "dollars.")
print("The minimum lot size is", min_lot_size, "pieces.")
# Out:
# The minimum total inventory costs is 14700.0 dollars.
# The minimum lot size is 140 pieces.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Problem 12: </b> A company has a badly designed product, but a huge advertising budget. The product sells well when it is first introducted. However, sales fall as people switch to a better product from a competitor. Given that the monthly sales S can be modeled by
#
# $S = 200t/(t+3)^2$, where t >=0, where S is in thousands of dollars and t is in months.
#
# After how many months will sales be maximized and what will the maximum in sales be?

# %%
from scipy.optimize import minimize_scalar

# Define the sales function
def sales_function(t):
    return 200 * t / (t + 3) ** 2

# Define the negative of the sales function (minimize_scalar finds minimum, so we use negative to find maximum)
def negative_sales_function(t):
    return -sales_function(t)

# Find the value of 't' that maximizes the sales function
result = minimize_scalar(negative_sales_function, bounds=(0, 100), method='bounded')

# Extract the optimal value of 't' and corresponding maximum sales
optimal_t = result.x
maximum_sales = -result.fun  # Convert back to positive value

# Round the values to two decimal places
optimal_t = round(optimal_t, 2)
maximum_sales = round(maximum_sales, 2)

print(f"After {optimal_t} months, the sales will be maximized at ${maximum_sales} thousand.")
# Out:
# After 3.0 months, the sales will be maximized at $16.67 thousand.

# %%
# replace values from problem set 

from scipy.optimize import minimize_scalar

# Define the sales function
def sales_function(t):
    return 210 * t / (t + 3) ** 2

# Define the negative of the sales function (minimize_scalar finds minimum, so we use negative to find maximum)
def negative_sales_function(t):
    return -sales_function(t)

# Find the value of 't' that maximizes the sales function
result = minimize_scalar(negative_sales_function, bounds=(0, 100), method='bounded')

# Extract the optimal value of 't' and corresponding maximum sales
optimal_t = result.x
maximum_sales = -result.fun  # Convert back to positive value

# Round the values to two decimal places
optimal_t = round(optimal_t, 2)
maximum_sales = round(maximum_sales, 2)

print(f"After {optimal_t} months, the sales will be maximized at ${maximum_sales} thousand.")
# Out:
# After 3.0 months, the sales will be maximized at $17.5 thousand.

# %%
# replace values from problem set 

from scipy.optimize import minimize_scalar

# Define the sales function
def sales_function(t):
    return 3 * t**2 - 9*t+239

# Define the negative of the sales function (minimize_scalar finds minimum, so we use negative to find maximum)
def negative_sales_function(t):
    return sales_function(t)

# Find the value of 't' that maximizes the sales function
result = minimize_scalar(negative_sales_function, bounds=(0, 100), method='bounded')

# Extract the optimal value of 't' and corresponding maximum sales
optimal_t = result.x
maximum_sales = -result.fun  # Convert back to positive value

# Round the values to two decimal places
optimal_t = round(optimal_t, 2)
maximum_sales = round(maximum_sales, 2)

print(f"After {optimal_t} months, the sales will be maximized at ${maximum_sales} thousand.")
# Out:
# After 1.5 months, the sales will be maximized at $-232.25 thousand.

# %%
import math

# Define the function f(x)
def f(x):
    return x + 1 - math.exp(x)

# Define the derivative f'(x)
def f_prime(x):
    return 1 - math.exp(x)

# Initial guess
x = 0.6

# Number of iterations
iterations = 7

print("Newton's Method for f(x) = 6x + 5 - e^x")
print("Initial estimate: x1 = 0.6\n")

# Perform iterations
for i in range(2, iterations + 1):
    x_next = x - f(x) / f_prime(x)
    print(f"x{i} = {x_next:.10f}")
    x = x_next
# Out:
# Newton's Method for f(x) = 6x + 5 - e^x
# Initial estimate: x1 = 0.6
#
# x2 = 0.3298215291
# x3 = 0.1739595582
# x4 = 0.0895003354
# x5 = 0.0454176045
# x6 = 0.0228806929
# x7 = 0.0114839732

# %%
import numpy as np
import matplotlib.pyplot as plt

fixed = 50000
variable = 18
price = 130

def cost(x):
    return fixed + variable * x

def revenue(x):
    return price * x

# break even occurs when the cost equals the revenue.  using algebra, this is solving for x
solve_x = fixed / (price - variable)
revenue_func = revenue(solve_x)

x = np.linspace(0, 600, 200)

plt.figure(figsize=(8,6))
plt.plot(x, cost(x), label='cost function: C(x) = 50000 + 18x', color='m')
plt.plot(x, revenue(x), label='revenue function: R(x) = 130x', color='c')
plt.scatter(solve_x, revenue_func, color='blue', zorder=5)

plt.title('cost and revenue functions')
plt.xlabel('pairs of shoes')
plt.ylabel('$')
plt.legend()
plt.show()

print(f"break-even point: {solve_x:.2f} pairs of shoes, total revenue = ${revenue_func:.2f}")
# Out:
# break-even point: 446.43 pairs of shoes, total revenue = $58035.71

# %%
from sympy import symbols, Eq, solve

m, b, d = symbols('m b d')

# Equations
eq1 = Eq(m + b + d, 17500000000)
eq2 = Eq(0.11*m + 0.07*b + 0.05*d, 1495000000)
eq3 = Eq(m, 2*d)

# Solve the system of equations
solution = solve((eq1, eq2, eq3), (m, b, d))
solution
# Out:
# {m: 9000000000.00000, b: 4000000000.00000, d: 4500000000.00000}

# %%
# Total number of reps
total = 275

# Loop through possible integer values for x and y
solutions = []
for x in range(1, total+1):
    for y in range(1, total+1):
        if 5*x + 6*y == total:
            team1 = 4*x
            team2 = x
            team3 = 5*y
            team4 = y
            solutions.append((team1, team2, team3, team4))

# Display solutions
for i, (t1, t2, t3, t4) in enumerate(solutions, start=1):
    print(f"Solution {i}:")
    print(f"Team 1: {t1}, Team 2: {t2}, Team 3: {t3}, Team 4: {t4}")
# Out:
# Solution 1:
# Team 1: 4, Team 2: 1, Team 3: 225, Team 4: 45
# Solution 2:
# Team 1: 28, Team 2: 7, Team 3: 200, Team 4: 40
# Solution 3:
# Team 1: 52, Team 2: 13, Team 3: 175, Team 4: 35
# Solution 4:
# Team 1: 76, Team 2: 19, Team 3: 150, Team 4: 30
# Solution 5:
# Team 1: 100, Team 2: 25, Team 3: 125, Team 4: 25
# Solution 6:
# Team 1: 124, Team 2: 31, Team 3: 100, Team 4: 20
# Solution 7:
# Team 1: 148, Team 2: 37, Team 3: 75, Team 4: 15
# Solution 8:
# Team 1: 172, Team 2: 43, Team 3: 50, Team 4: 10
# Solution 9:
# Team 1: 196, Team 2: 49, Team 3: 25, Team 4: 5

# %%
import numpy as np

            
A = np.array([[6,8,1], # cherry
              [6,4,1], # almond
              [5,7,1]]) # raisin
# columns are sugar, chocolate and milk

# since the problem only asks for supplier K, we use the K column only
K = np.array([3, 5, 2])  # dollars per unit

# perform matrix multiplication to find the cost per batch for each brownie
cost = A.dot(K)

# multiply by 100 to calculate the cost of 100 batches of each candy
hundred = 100 * cost

print("cost for 100 batches each: (cherry, almond, raisin): ", hundred)
# Out:
# cost for 100 batches each: (cherry, almond, raisin):  [6000 4000 5200]

# %%
import numpy as np

A = np.array([
    [1, 1, 1], # x + y + z = 28000 (total seats)
    [48, 36, 24], # 48x + 36y + 24z = 750000 (total revenue)
    [24, 36, 12]  # 24x + 36y + 12z = 400000 (half courtside, all first level, half upper deck sold 
])

b = np.array([28000, 750000, 400000]) # constants from equations

values = np.linalg.solve(A, b)
print(values)
# Out:
# [ 2555.55555556  1388.88888889 24055.55555556]

# %%
import numpy as np
from scipy.optimize import linprog

# make the coefficients negative to find the maximum.  scipy's linprog minimizes by default
P = [-0.25, -0.16]

A = [
    [6, 2],       # co2
    [3, 4]        # lead
]
b = [18000, 12000]

x_bounds = (0, None) # none means no upper limit
y_bounds = (0, None)

result = linprog(P, A_ub=A, b_ub=b, bounds=[x_bounds, y_bounds], method='highs')
print(result)
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -826.6666666666666
#               x: [ 2.667e+03  1.000e+03]
#             nit: 2
#           lower:  residual: [ 2.667e+03  1.000e+03]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00]
#                  marginals: [-2.889e-02 -2.556e-02]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0

# %%
import numpy as np
from scipy.optimize import linprog

# objective function
c = np.array([2400, 1100])

A = np.array([
    [1, 1],        # t + a <= 45
    [-1, -1],      # -t - a <= -30 (equivalent to T + A >= 30)
    [-1, 0],       # -t <= -1 (t >= 1)
    [0, -1],       # -a <= -10 (a >= 10)
    [-1.5, 1]      # -1.5t + a <= 0 (a <= 1.5T)
])

b = np.array([
    45,   
    -30,  
    -1,   
    -10,  
    0     
])

x_bounds = (0, None) # none means no upper limit
y_bounds = (0, None)

result = linprog(c, A_ub=A, b_ub=b, bounds=[x_bounds, y_bounds], method='highs')
print(result)
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: 48600.0
#               x: [ 1.200e+01  1.800e+01]
#             nit: 2
#           lower:  residual: [ 1.200e+01  1.800e+01]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 1.500e+01  0.000e+00  1.100e+01  8.000e+00
#                               0.000e+00]
#                  marginals: [-0.000e+00 -1.620e+03 -0.000e+00 -0.000e+00
#                              -5.200e+02]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0

# %%
import numpy as np
from scipy.optimize import linprog

# objective function
c = np.array([0.06, 0.08, 0.01])

# convert ≥ constraints to ≤ by multiplying both sides by -1
A = np.array([
    [-4, -1, -10], 
    [-3, -2, -1],   
    [0, -4, -5]     
])

b = np.array([-10, -12, -20])

pill_bounds = [(0, None), (0, None), (0, None)]

result = linprog(c, A_ub=A, b_ub=b, bounds=pill_bounds, method='highs')
print(result)
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: 0.12
#               x: [ 0.000e+00  0.000e+00  1.200e+01]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  1.200e+01]
#                  marginals: [ 3.000e-02  6.000e-02  0.000e+00]
#           upper:  residual: [       inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 1.100e+02  0.000e+00  4.000e+01]
#                  marginals: [-0.000e+00 -1.000e-02 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0

# %%
import sympy as sp

t = sp.symbols('t')

P = (t**2 + 100) * sp.log(t + 2)

dev_P = sp.diff(P, t)

# Evaluate at t = 6 (year 2006) and t = 16 (year 2016)
rate_2006 = dev_P.subs(t, 6).evalf()
rate_2016 = dev_P.subs(t, 16).evalf()

print(rate_2006)
print(rate_2016)
# Out:
# 41.9532985001580
# 112.269674030455

# %%
import sympy as sp

t = sp.symbols('t')

A = (12*t**5) / (2*sp.exp(t) + 3*t)

dev_A = sp.diff(A, t)

month_2 = dev_A.subs(t, 2).evalf()
month_4 = dev_A.subs(t, 4).evalf()
month_6 = dev_A.subs(t, 6).evalf()

print(month_2)
print(month_4)
print(month_6)
# Out:
# 30.3898136604199
# 32.8764417873259
# -16.7969907566968
