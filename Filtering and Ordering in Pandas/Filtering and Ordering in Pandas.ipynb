# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd
pd.set_option('display.max.rows', 10)

# %%
df = pd.read_csv(r'/Users/timothypark/Documents/portfolios/timpark99.github.io/Filtering and Ordering in Pandas/Electric_Vehicle_Population_Size_History_By_County_.csv')

# %%
df
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 20814                                1
# 20815                                1
# 20816                              744
# 20817                               14
# 20818                                3
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            0                           7
# 1                                            2                           3
# 2                                            1                           1
# 3                                            0                           0
# 4                                            1                           1
# ...                                        ...                         ...
# 20814                                        0                           1
# 20815                                        0                           1
# 20816                                      350                       1,094
# 20817                                        2                          16
# 20818                                        1                           4
#
#       Non-Electric Vehicle Total Total Vehicles  Percent Electric Vehicles
# 0                            460            467                       1.50
# 1                            188            191                       1.57
# 2                             32             33                       3.03
# 3                          3,575          3,575                       0.00
# 4                             83             84                       1.19
# ...                          ...            ...                        ...
# 20814                         14             15                       6.67
# 20815                         10             11                       9.09
# 20816                     62,257         63,351                       1.73
# 20817                      2,724          2,740                       0.58
# 20818                        271            275                       1.45
#
# [20819 rows x 10 columns]

# %%
df.dtypes
# Out:
# Date                                         object
# County                                       object
# State                                        object
# Vehicle Primary Use                          object
# Battery Electric Vehicles (BEVs)             object
# Plug-In Hybrid Electric Vehicles (PHEVs)     object
# Electric Vehicle (EV) Total                  object
# Non-Electric Vehicle Total                   object
# Total Vehicles                               object
# Percent Electric Vehicles                   float64
# dtype: object

# %%
# initially tried to change dtype to int but could not because the commas were in the object
# replace eliminates the commas in the numbers
# to_numeric will change our data type to int

df = df.replace(',','', regex=True)
df['Total Vehicles'] = pd.to_numeric(df['Total Vehicles'])

# %%
df.dtypes
# Out:
# Date                                         object
# County                                       object
# State                                        object
# Vehicle Primary Use                          object
# Battery Electric Vehicles (BEVs)             object
# Plug-In Hybrid Electric Vehicles (PHEVs)     object
# Electric Vehicle (EV) Total                  object
# Non-Electric Vehicle Total                   object
# Total Vehicles                                int64
# Percent Electric Vehicles                   float64
# dtype: object

# %%
df[df['Total Vehicles'] < 10]
# Out:
#                     Date    County State Vehicle Primary Use  \
# 8          March 31 2020    DeKalb    IN           Passenger
# 13      November 30 2020  Manassas    VA           Passenger
# 16           May 31 2020    Monroe    IL           Passenger
# 22      February 29 2020    Owyhee    ID           Passenger
# 23          June 30 2022   Clinton    PA           Passenger
# ...                  ...       ...   ...                 ...
# 20757    January 31 2024    Ulster    NY           Passenger
# 20778   February 28 2019  Franklin    MA           Passenger
# 20789  September 30 2023  Sheridan    WY           Passenger
# 20790        May 31 2022     Eagle    CO           Passenger
# 20795      April 30 2023    Tooele    UT           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 8                                    1
# 13                                   0
# 16                                   1
# 22                                   1
# 23                                   1
# ...                                ...
# 20757                                1
# 20778                                0
# 20789                                1
# 20790                                1
# 20795                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 8                                            0                           1
# 13                                           1                           1
# 16                                           0                           1
# 22                                           0                           1
# 23                                           0                           1
# ...                                        ...                         ...
# 20757                                        0                           1
# 20778                                        1                           1
# 20789                                        0                           1
# 20790                                        0                           1
# 20795                                        0                           1
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 8                              1               2                      50.00
# 13                             5               6                      16.67
# 16                             3               4                      25.00
# 22                             3               4                      25.00
# 23                             1               2                      50.00
# ...                          ...             ...                        ...
# 20757                          5               6                      16.67
# 20778                          1               2                      50.00
# 20789                          3               4                      25.00
# 20790                          7               8                      12.50
# 20795                          8               9                      11.11
#
# [1501 rows x 10 columns]

# %%
# for demonstration purposes, drop duplicates of same county name

df['County'].drop_duplicates()
# Out:
# 0             Riverside
# 1        Prince William
# 2                Dakota
# 3                 Ferry
# 4               Douglas
#               ...
# 9152       Spotsylvania
# 9504          Worcester
# 12905             Union
# 14186        Bernalillo
# 15083             Brown
# Name: County, Length: 312, dtype: object

# %%
df
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 20814                                1
# 20815                                1
# 20816                              744
# 20817                               14
# 20818                                3
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            0                           7
# 1                                            2                           3
# 2                                            1                           1
# 3                                            0                           0
# 4                                            1                           1
# ...                                        ...                         ...
# 20814                                        0                           1
# 20815                                        0                           1
# 20816                                      350                        1094
# 20817                                        2                          16
# 20818                                        1                           4
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 0                            460             467                       1.50
# 1                            188             191                       1.57
# 2                             32              33                       3.03
# 3                           3575            3575                       0.00
# 4                             83              84                       1.19
# ...                          ...             ...                        ...
# 20814                         14              15                       6.67
# 20815                         10              11                       9.09
# 20816                      62257           63351                       1.73
# 20817                       2724            2740                       0.58
# 20818                        271             275                       1.45
#
# [20819 rows x 10 columns]

# %%
# isin function checks whether each element in the DataFrame is contained in values

specific_counties = ['DeKalb', 'Manassas']
df[df['County'].isin(specific_counties)]
# Out:
#                     Date    County State Vehicle Primary Use  \
# 8          March 31 2020    DeKalb    IN           Passenger
# 13      November 30 2020  Manassas    VA           Passenger
# 46         April 30 2020  Manassas    VA           Passenger
# 94           May 31 2017    DeKalb    IN           Passenger
# 222        March 31 2022    DeKalb    GA           Passenger
# ...                  ...       ...   ...                 ...
# 20162  September 30 2018    DeKalb    IN           Passenger
# 20570    January 31 2019    DeKalb    GA           Passenger
# 20639    January 31 2018    DeKalb    IN           Passenger
# 20652    October 31 2023    DeKalb    GA           Passenger
# 20755    January 31 2018    DeKalb    GA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 8                                    1
# 13                                   0
# 46                                   0
# 94                                   1
# 222                                  1
# ...                                ...
# 20162                                1
# 20570                                1
# 20639                                1
# 20652                                2
# 20755                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 8                                            0                           1
# 13                                           1                           1
# 46                                           1                           1
# 94                                           0                           1
# 222                                          0                           1
# ...                                        ...                         ...
# 20162                                        0                           1
# 20570                                        0                           1
# 20639                                        0                           1
# 20652                                        0                           2
# 20755                                        0                           1
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 8                              1               2                      50.00
# 13                             5               6                      16.67
# 46                             5               6                      16.67
# 94                             1               2                      50.00
# 222                           56              57                       1.75
# ...                          ...             ...                        ...
# 20162                          1               2                      50.00
# 20570                         79              80                       1.25
# 20639                          1               2                      50.00
# 20652                         35              37                       5.41
# 20755                         86              87                       1.15
#
# [206 rows x 10 columns]

# %%
# contains function
# na=False ignores null values

df[df['County'].str.contains('Eagle', na=False)]
# Out:
#                    Date County State Vehicle Primary Use  \
# 732        July 31 2020  Eagle    CO           Passenger
# 807     October 31 2022  Eagle    CO           Passenger
# 982         May 31 2020  Eagle    CO           Passenger
# 1444   February 28 2022  Eagle    CO           Passenger
# 1525       July 31 2021  Eagle    CO           Passenger
# ...                 ...    ...   ...                 ...
# 20279      June 30 2019  Eagle    CO           Passenger
# 20358    August 31 2018  Eagle    CO           Passenger
# 20454      June 30 2017  Eagle    CO           Passenger
# 20623       May 31 2018  Eagle    CO           Passenger
# 20790       May 31 2022  Eagle    CO           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 732                                  1
# 807                                  1
# 982                                  1
# 1444                                 1
# 1525                                 1
# ...                                ...
# 20279                                1
# 20358                                1
# 20454                                1
# 20623                                1
# 20790                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 732                                          0                           1
# 807                                          0                           1
# 982                                          0                           1
# 1444                                         0                           1
# 1525                                         0                           1
# ...                                        ...                         ...
# 20279                                        0                           1
# 20358                                        0                           1
# 20454                                        0                           1
# 20623                                        0                           1
# 20790                                        0                           1
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 732                            8               9                      11.11
# 807                            8               9                      11.11
# 982                            9              10                      10.00
# 1444                           7               8                      12.50
# 1525                           9              10                      10.00
# ...                          ...             ...                        ...
# 20279                          6               7                      14.29
# 20358                          5               6                      16.67
# 20454                          7               8                      12.50
# 20623                          6               7                      14.29
# 20790                          7               8                      12.50
#
# [78 rows x 10 columns]

# %%
# filtering on index

df2 = df.set_index('County')
df2
# Out:
#                              Date State Vehicle Primary Use  \
# County
# Riverside       September 30 2022    CA           Passenger
# Prince William   December 31 2022    VA           Passenger
# Dakota            January 31 2020    MN           Passenger
# Ferry                June 30 2022    WA               Truck
# Douglas              July 31 2021    CO           Passenger
# ...                           ...   ...                 ...
# Rockingham        January 31 2023    NH           Passenger
# Carson City          July 31 2020    NV           Passenger
# Island           February 28 2022    WA           Passenger
# San Diego        December 31 2020    CA           Passenger
# Goochland        November 30 2019    VA           Passenger
#
#                Battery Electric Vehicles (BEVs)  \
# County
# Riverside                                     7
# Prince William                                1
# Dakota                                        0
# Ferry                                         0
# Douglas                                       0
# ...                                         ...
# Rockingham                                    1
# Carson City                                   1
# Island                                      744
# San Diego                                    14
# Goochland                                     3
#
#                Plug-In Hybrid Electric Vehicles (PHEVs)  \
# County
# Riverside                                             0
# Prince William                                        2
# Dakota                                                1
# Ferry                                                 0
# Douglas                                               1
# ...                                                 ...
# Rockingham                                            0
# Carson City                                           0
# Island                                              350
# San Diego                                             2
# Goochland                                             1
#
#                Electric Vehicle (EV) Total Non-Electric Vehicle Total  \
# County
# Riverside                                7                        460
# Prince William                           3                        188
# Dakota                                   1                         32
# Ferry                                    0                       3575
# Douglas                                  1                         83
# ...                                    ...                        ...
# Rockingham                               1                         14
# Carson City                              1                         10
# Island                                1094                      62257
# San Diego                               16                       2724
# Goochland                                4                        271
#
#                 Total Vehicles  Percent Electric Vehicles
# County
# Riverside                  467                       1.50
# Prince William             191                       1.57
# Dakota                      33                       3.03
# Ferry                     3575                       0.00
# Douglas                     84                       1.19
# ...                        ...                        ...
# Rockingham                  15                       6.67
# Carson City                 11                       9.09
# Island                   63351                       1.73
# San Diego                 2740                       0.58
# Goochland                  275                       1.45
#
# [20819 rows x 9 columns]

# %%
# axis=0 is the row axis and axis=1 is the column axis

df2.filter(items = ['State', 'Vehicle Primary Use'], axis=1)
# Out:
#                State Vehicle Primary Use
# County
# Riverside         CA           Passenger
# Prince William    VA           Passenger
# Dakota            MN           Passenger
# Ferry             WA               Truck
# Douglas           CO           Passenger
# ...              ...                 ...
# Rockingham        NH           Passenger
# Carson City       NV           Passenger
# Island            WA           Passenger
# San Diego         CA           Passenger
# Goochland         VA           Passenger
#
# [20819 rows x 2 columns]

# %%
df2.filter(items = ['Island'], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df2.filter(items = ['Island'], axis=0)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5537, in NDFrame.filter(self, items, like, regex, axis)
#    5535     name = self._get_axis_name(axis)
#    5536     # error: Keywords must be strings
# -> 5537     return self.reindex(  # type: ignore[misc]
#    5538         **{name: [r for r in items if r in labels]}  # type: ignore[arg-type]
#    5539     )
#    5540 elif like:
#    5542     def f(x) -> bool_t:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5055, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5036 @doc(
#    5037     NDFrame.reindex,
#    5038     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5053     tolerance=None,
#    5054 ) -> DataFrame:
# -> 5055     return super().reindex(
#    5056         labels=labels,
#    5057         index=index,
#    5058         columns=columns,
#    5059         axis=axis,
#    5060         method=method,
#    5061         copy=copy,
#    5062         level=level,
#    5063         fill_value=fill_value,
#    5064         limit=limit,
#    5065         tolerance=tolerance,
#    5066     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5360, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5357     return self._reindex_multi(axes, copy, fill_value)
#    5359 # perform the reindex on the axes
# -> 5360 return self._reindex_axes(
#    5361     axes, level, limit, tolerance, method, fill_value, copy
#    5362 ).__finalize__(self, method="reindex")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4896, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4894 index = axes["index"]
#    4895 if index is not None:
# -> 4896     frame = frame._reindex_index(
#    4897         index, method, copy, level, fill_value, limit, tolerance
#    4898     )
#    4900 return frame
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4912, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4902 def _reindex_index(
#    4903     self,
#    4904     new_index,
#    (...)
#    4910     tolerance=None,
#    4911 ):
# -> 4912     new_index, indexer = self.index.reindex(
#    4913         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4914     )
#    4915     return self._reindex_with_indexers(
#    4916         {0: [new_index, indexer]},
#    4917         copy=copy,
#    4918         fill_value=fill_value,
#    4919         allow_dups=False,
#    4920     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4275, in Index.reindex(self, target, method, level, limit, tolerance)
#    4272     raise ValueError("cannot handle a non-unique multi-index!")
#    4273 elif not self.is_unique:
#    4274     # GH#42568
# -> 4275     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4276 else:
#    4277     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
