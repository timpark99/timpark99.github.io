# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd
pd.set_option('display.max.rows', 10)

# %%
df = pd.read_csv(r'/Users/timothypark/Documents/portfolios/timpark99.github.io/Filtering and Ordering in Pandas/Electric_Vehicle_Population_Size_History_By_County_.csv')

# %%
df
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 20814    January 31 2023      Rockingham    NH           Passenger
# 20815       July 31 2020     Carson City    NV           Passenger
# 20816   February 28 2022          Island    WA           Passenger
# 20817   December 31 2020       San Diego    CA           Passenger
# 20818   November 30 2019       Goochland    VA           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 20814                                1
# 20815                                1
# 20816                              744
# 20817                               14
# 20818                                3
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            0                           7
# 1                                            2                           3
# 2                                            1                           1
# 3                                            0                           0
# 4                                            1                           1
# ...                                        ...                         ...
# 20814                                        0                           1
# 20815                                        0                           1
# 20816                                      350                       1,094
# 20817                                        2                          16
# 20818                                        1                           4
#
#       Non-Electric Vehicle Total Total Vehicles  Percent Electric Vehicles
# 0                            460            467                       1.50
# 1                            188            191                       1.57
# 2                             32             33                       3.03
# 3                          3,575          3,575                       0.00
# 4                             83             84                       1.19
# ...                          ...            ...                        ...
# 20814                         14             15                       6.67
# 20815                         10             11                       9.09
# 20816                     62,257         63,351                       1.73
# 20817                      2,724          2,740                       0.58
# 20818                        271            275                       1.45
#
# [20819 rows x 10 columns]

# %%
df.dtypes
# Out:
# Date                                         object
# County                                       object
# State                                        object
# Vehicle Primary Use                          object
# Battery Electric Vehicles (BEVs)             object
# Plug-In Hybrid Electric Vehicles (PHEVs)     object
# Electric Vehicle (EV) Total                  object
# Non-Electric Vehicle Total                   object
# Total Vehicles                               object
# Percent Electric Vehicles                   float64
# dtype: object

# %%
# initially tried to change dtype to int but could not because the commas were in the object
# replace eliminates the commas in the numbers
# to_numeric will change our data type to int

df = df.replace(',','', regex=True)
df['Total Vehicles'] = pd.to_numeric(df['Total Vehicles'])

# %%
df.dtypes
# Out:
# Date                                         object
# County                                       object
# State                                        object
# Vehicle Primary Use                          object
# Battery Electric Vehicles (BEVs)             object
# Plug-In Hybrid Electric Vehicles (PHEVs)     object
# Electric Vehicle (EV) Total                  object
# Non-Electric Vehicle Total                   object
# Total Vehicles                                int64
# Percent Electric Vehicles                   float64
# dtype: object

# %%
# filters dataset to where it will show data only when Total Vehicles is less than 10

df[df['Total Vehicles'] < 10]
# Out:
#                     Date    County State Vehicle Primary Use  \
# 8          March 31 2020    DeKalb    IN           Passenger
# 13      November 30 2020  Manassas    VA           Passenger
# 16           May 31 2020    Monroe    IL           Passenger
# 22      February 29 2020    Owyhee    ID           Passenger
# 23          June 30 2022   Clinton    PA           Passenger
# ...                  ...       ...   ...                 ...
# 20757    January 31 2024    Ulster    NY           Passenger
# 20778   February 28 2019  Franklin    MA           Passenger
# 20789  September 30 2023  Sheridan    WY           Passenger
# 20790        May 31 2022     Eagle    CO           Passenger
# 20795      April 30 2023    Tooele    UT           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 8                                    1
# 13                                   0
# 16                                   1
# 22                                   1
# 23                                   1
# ...                                ...
# 20757                                1
# 20778                                0
# 20789                                1
# 20790                                1
# 20795                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 8                                            0                           1
# 13                                           1                           1
# 16                                           0                           1
# 22                                           0                           1
# 23                                           0                           1
# ...                                        ...                         ...
# 20757                                        0                           1
# 20778                                        1                           1
# 20789                                        0                           1
# 20790                                        0                           1
# 20795                                        0                           1
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 8                              1               2                      50.00
# 13                             5               6                      16.67
# 16                             3               4                      25.00
# 22                             3               4                      25.00
# 23                             1               2                      50.00
# ...                          ...             ...                        ...
# 20757                          5               6                      16.67
# 20778                          1               2                      50.00
# 20789                          3               4                      25.00
# 20790                          7               8                      12.50
# 20795                          8               9                      11.11
#
# [1501 rows x 10 columns]

# %%
# for demonstration purposes, drop duplicates of same county name but keep the first county that shows up in order to keep unique rows

df = df.drop_duplicates(subset='County', keep='first')

# %%
df
# Out:
#                     Date          County State Vehicle Primary Use  \
# 0      September 30 2022       Riverside    CA           Passenger
# 1       December 31 2022  Prince William    VA           Passenger
# 2        January 31 2020          Dakota    MN           Passenger
# 3           June 30 2022           Ferry    WA               Truck
# 4           July 31 2021         Douglas    CO           Passenger
# ...                  ...             ...   ...                 ...
# 9152    December 31 2023    Spotsylvania    VA           Passenger
# 9504    December 31 2023       Worcester    MA           Passenger
# 12905    January 31 2017           Union    OH           Passenger
# 14186   November 30 2021      Bernalillo    NM           Passenger
# 15083    January 31 2017           Brown    WI           Passenger
#
#       Battery Electric Vehicles (BEVs)  \
# 0                                    7
# 1                                    1
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 9152                                 0
# 9504                                 1
# 12905                                1
# 14186                                1
# 15083                                1
#
#       Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# 0                                            0                           7
# 1                                            2                           3
# 2                                            1                           1
# 3                                            0                           0
# 4                                            1                           1
# ...                                        ...                         ...
# 9152                                         1                           1
# 9504                                         0                           1
# 12905                                        0                           1
# 14186                                        0                           1
# 15083                                        0                           1
#
#       Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# 0                            460             467                       1.50
# 1                            188             191                       1.57
# 2                             32              33                       3.03
# 3                           3575            3575                       0.00
# 4                             83              84                       1.19
# ...                          ...             ...                        ...
# 9152                          21              22                       4.55
# 9504                           9              10                      10.00
# 12905                          4               5                      20.00
# 14186                        110             111                       0.90
# 15083                         46              47                       2.13
#
# [312 rows x 10 columns]

# %%
# isin function checks whether each element in the DataFrame is contained in values

specific_counties = ['DeKalb', 'Manassas']
df[df['County'].isin(specific_counties)]
# Out:
#                 Date    County State Vehicle Primary Use  \
# 8      March 31 2020    DeKalb    IN           Passenger
# 13  November 30 2020  Manassas    VA           Passenger
#
#    Battery Electric Vehicles (BEVs) Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 8                                 1                                        0
# 13                                0                                        1
#
#    Electric Vehicle (EV) Total Non-Electric Vehicle Total  Total Vehicles  \
# 8                            1                          1               2
# 13                           1                          5               6
#
#     Percent Electric Vehicles
# 8                       50.00
# 13                      16.67

# %%
# contains function
# na=False ignores null values

df[df['County'].str.contains('Eagle', na=False)]
# Out:
#              Date County State Vehicle Primary Use  \
# 732  July 31 2020  Eagle    CO           Passenger
#
#     Battery Electric Vehicles (BEVs) Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 732                                1                                        0
#
#     Electric Vehicle (EV) Total Non-Electric Vehicle Total  Total Vehicles  \
# 732                           1                          8               9
#
#      Percent Electric Vehicles
# 732                      11.11

# %%
# filtering on index
# change the index to County

df2 = df.set_index('County')
df2
# Out:
#                              Date State Vehicle Primary Use  \
# County
# Riverside       September 30 2022    CA           Passenger
# Prince William   December 31 2022    VA           Passenger
# Dakota            January 31 2020    MN           Passenger
# Ferry                June 30 2022    WA               Truck
# Douglas              July 31 2021    CO           Passenger
# ...                           ...   ...                 ...
# Spotsylvania     December 31 2023    VA           Passenger
# Worcester        December 31 2023    MA           Passenger
# Union             January 31 2017    OH           Passenger
# Bernalillo       November 30 2021    NM           Passenger
# Brown             January 31 2017    WI           Passenger
#
#                Battery Electric Vehicles (BEVs)  \
# County
# Riverside                                     7
# Prince William                                1
# Dakota                                        0
# Ferry                                         0
# Douglas                                       0
# ...                                         ...
# Spotsylvania                                  0
# Worcester                                     1
# Union                                         1
# Bernalillo                                    1
# Brown                                         1
#
#                Plug-In Hybrid Electric Vehicles (PHEVs)  \
# County
# Riverside                                             0
# Prince William                                        2
# Dakota                                                1
# Ferry                                                 0
# Douglas                                               1
# ...                                                 ...
# Spotsylvania                                          1
# Worcester                                             0
# Union                                                 0
# Bernalillo                                            0
# Brown                                                 0
#
#                Electric Vehicle (EV) Total Non-Electric Vehicle Total  \
# County
# Riverside                                7                        460
# Prince William                           3                        188
# Dakota                                   1                         32
# Ferry                                    0                       3575
# Douglas                                  1                         83
# ...                                    ...                        ...
# Spotsylvania                             1                         21
# Worcester                                1                          9
# Union                                    1                          4
# Bernalillo                               1                        110
# Brown                                    1                         46
#
#                 Total Vehicles  Percent Electric Vehicles
# County
# Riverside                  467                       1.50
# Prince William             191                       1.57
# Dakota                      33                       3.03
# Ferry                     3575                       0.00
# Douglas                     84                       1.19
# ...                        ...                        ...
# Spotsylvania                22                       4.55
# Worcester                   10                      10.00
# Union                        5                      20.00
# Bernalillo                 111                       0.90
# Brown                       47                       2.13
#
# [312 rows x 9 columns]

# %%
# axis=1 is the column axis and it will give us column data for specified items

df2.filter(items = ['State', 'Vehicle Primary Use'], axis=1)
# Out:
#                State Vehicle Primary Use
# County
# Riverside         CA           Passenger
# Prince William    VA           Passenger
# Dakota            MN           Passenger
# Ferry             WA               Truck
# Douglas           CO           Passenger
# ...              ...                 ...
# Spotsylvania      VA           Passenger
# Worcester         MA           Passenger
# Union             OH           Passenger
# Bernalillo        NM           Passenger
# Brown             WI           Passenger
#
# [312 rows x 2 columns]

# %%
# axis=0 is the row axis and it will give us the row data when we specify items = 'County'

df2.filter(items = ['Island'], axis=0)
# Out:
#                     Date State Vehicle Primary Use  \
# County
# Island  December 31 2021    WA               Truck
#
#        Battery Electric Vehicles (BEVs)  \
# County
# Island                                0
#
#        Plug-In Hybrid Electric Vehicles (PHEVs) Electric Vehicle (EV) Total  \
# County
# Island                                        0                           0
#
#        Non-Electric Vehicle Total  Total Vehicles  Percent Electric Vehicles
# County
# Island                      21488           21488                        0.0

# %%
# loc will give you the value of the targeted index

df2.loc['Union']
# Out:
# Date                                        January 31 2017
# State                                                    OH
# Vehicle Primary Use                               Passenger
# Battery Electric Vehicles (BEVs)                          1
# Plug-In Hybrid Electric Vehicles (PHEVs)                  0
# Electric Vehicle (EV) Total                               1
# Non-Electric Vehicle Total                                4
# Total Vehicles                                            5
# Percent Electric Vehicles                              20.0
# Name: Union, dtype: object

# %%
df2.iloc['Union']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df2.iloc['Union']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1653, in _iLocIndexer._getitem_axis(self, key, axis)
#    1651 key = item_from_zerodim(key)
#    1652 if not is_integer(key):
# -> 1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
#    1656 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key
