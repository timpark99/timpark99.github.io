# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/timothypark/Documents/portfolios/timpark99.github.io/Pandas Visualizations/Sleep_Efficiency.csv")
df.head()
# Out:
#    ID  Age  Gender              Bedtime          Wakeup time  Sleep duration  \
# 0   1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00             6.0
# 1   2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00             7.0
# 2   3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00             8.0
# 3   4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00             6.0
# 4   5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00             8.0
#
#    Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0              0.88                    18                     70
# 1              0.66                    19                     28
# 2              0.89                    20                     70
# 3              0.51                    23                     25
# 4              0.76                    27                     55
#
#    Light sleep percentage  Awakenings  Caffeine consumption  \
# ...

# %%
plt.style.use('seaborn-v0_8-dark-palette')

# %%
df.plot(kind='line', title='Sleep Efficiency', x='Caffeine consumption', y='Awakenings')
# Out:
# <Axes: title={'center': 'Sleep Efficiency'}, xlabel='Caffeine consumption'>

# %%
df.plot(kind='bar', x='Age', y='Sleep duration', stacked=True)
# Out:
# <Axes: xlabel='Age'>
